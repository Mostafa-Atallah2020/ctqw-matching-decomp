# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f"./../")

from src.utils.basis_transformation import compose_transformations, transformation_to_circuit, print_transformation, create_transformation_from_swaps, compose_multiple_transformations
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Example 1: Compose two transformations
tr1 = {'001': '111', '111': '001'}
tr2 = {'000': '010', '010': '000', '001': '011', '011': '001'}

print_transformation(tr1, "Transformation TR1")
print_transformation(tr2, "Transformation TR2")

composed = compose_transformations(tr1, tr2)
print_transformation(composed, "Composed transformation (TR2 ∘ TR1)")

circuit = transformation_to_circuit(composed)
print("\nCircuit:")
print(circuit)
# Out:
# Transformation TR1:
# |001⟩ → |111⟩
# |111⟩ → |001⟩
#
# Transformation TR2:
# |000⟩ → |010⟩
# |001⟩ → |011⟩
# |010⟩ → |000⟩
# |011⟩ → |001⟩
#
# Composed transformation (TR2 ∘ TR1):
# |000⟩ → |010⟩
# |001⟩ → |111⟩
# |010⟩ → |000⟩
# |011⟩ → |001⟩
# |111⟩ → |011⟩
#
# Circuit:
#      ┌───┐     ┌───┐
# q_0: ┤ X ├──■──┤ X ├──■─────────■─────────■────■──
#      └───┘┌─┴─┐└───┘┌─┴─┐┌───┐  │  ┌───┐┌─┴─┐  │
# q_1: ─────┤ X ├─────┤ X ├┤ X ├──■──┤ X ├┤ X ├──■──
#      ┌───┐└─┬─┘┌───┐└─┬─┘└───┘┌─┴─┐└───┘└─┬─┘┌─┴─┐
# q_2: ┤ X ├──■──┤ X ├──■───────┤ X ├───────■──┤ X ├
#      └───┘     └───┘          └───┘          └───┘
