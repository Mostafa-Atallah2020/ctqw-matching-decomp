# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.circuit import Parameter

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f"./../")

# %%
psi00 = Statevector.from_label('00')
psi000 = Statevector.from_label('000')
# print("Initial state:")
# psi00.draw('latex')

# %%
from src.graphs import DiagonalEdgeGraph

edges = {('01', '10')}
graph = DiagonalEdgeGraph(edges)
# graph._debug_fixed_analysis()
qc = graph.get_qc()
qc.draw('mpl')

# %%
print("Final state after applying the circuit:")
final_state = psi00.evolve(qc)
final_state.draw('latex')
# Out:
# Final state after applying the circuit:
# $$- \frac{\sqrt{2} i}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %%
edges = {('00', '11')}
graph = DiagonalEdgeGraph(edges)
qc = graph.get_qc()
qc.draw('mpl')

# %%
print("Final state after applying the circuit:")
final_state = psi00.evolve(qc)
final_state.draw('latex')
# Out:
# Final state after applying the circuit:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2} i}{2} |11\rangle$$

# %%
edges = {('00', '11'), ('01', '10')}
graph = DiagonalEdgeGraph(edges)
qc = graph.get_qc()
qc.draw('mpl')

# %%
print("Final state after applying the circuit:")
final_state = psi00.evolve(qc)
final_state.draw('latex')
# Out:
# Final state after applying the circuit:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{i}{2} |01\rangle+\frac{\sqrt{2} i}{4} |10\rangle- \frac{\sqrt{2}}{4} |11\rangle$$

# %%
edges = {('000', '111')}
graph = DiagonalEdgeGraph(edges)
qc = graph.get_qc()
# print(graph.best_candidate.edges)
qc.draw('mpl')

# %%
print("Final state after applying the circuit:")
final_state = psi000.evolve(qc)
final_state.draw('latex')
# Out:
# Final state after applying the circuit:
# $$\frac{\sqrt{2}}{2} |000\rangle- \frac{\sqrt{2} i}{2} |111\rangle$$
