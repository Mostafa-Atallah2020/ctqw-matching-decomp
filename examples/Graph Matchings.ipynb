# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f"./../")

from src.graphs import StaticGraph, ParallelEdgeGraph, IntersectingEdgesGraph, MultiEdgeGraph, DiagonalEdgeGraph,NonDiagonalEdgeGraph
from collections import defaultdict
from src.edge import Edge

# %%
#edges = {('10', '11'), ('00', '01'), ('00', '11'), ('01', '11'), ('00', '10'), ('01', '10')}

#edges = {('01', '11'), ('00', '11'), ('10', '11')}

#edges = {('01', '11'), ('00', '11'), ('00', '10')}

#edges = {('01', '11'), ('00', '11'), ('00', '10'), ('10', '11')}

#edges = {('00', '11'), ('00', '10'), ('01', '10'), ('01', '11')}

edges = {('00', '11'), ('01', '10'), ('00', '10'), ('01', '11'), ('10', '11')}

# %%
G = StaticGraph(edges)
G.draw()

# %%
G = IntersectingEdgesGraph(edges)
for g in G.subgraphs:
    display(g.draw())
    qc = g.get_qc(simplified=True)
    display(qc.draw('mpl'))
    print(g.edges)
# Out:
# None
# {('00', '10'), ('01', '11')}
# None
# {('01', '10'), ('00', '11')}
# None
# {('10', '11')}
